# %% [markdown]
# cf. [Errors and Exceptions, the Python Tutorial](https://docs.python.org/3/tutorial/errors.html)

# %%
while True print ('Hello world')
# Out:
#   File "<ipython-input-1-1201eae45e42>", line 1
#     while True print ('Hello world')
#                    ^
# SyntaxError: invalid syntax

# %%
# while True: print ('Hello world')
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# ...

# %% [markdown]
# Errors detected during execution are called *exceptions* and are not unconditionally fatal; you'll soon learn how to handle them in Python programs.

# %%
10 * (1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-0b280f36835c> in <module>()
# ----> 1 10 * (1/0)
#
# ZeroDivisionError: integer division or modulo by zero

# %%
4 + spam * 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c8ef1c0a2ff8> in <module>()
# ----> 1 4 + spam * 3
#
# NameError: name 'spam' is not defined

# %%
'2' + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d2b23a1db757> in <module>()
# ----> 1 '2' + 2
#
# TypeError: cannot concatenate 'str' and 'int' objects

# %% [markdown]
# cf. [8.3 Handling Exceptions](https://docs.python.org/3/tutorial/errors.html)

# %% [markdown]
# ## Handling Exceptions

# %%
while True:
    try:
        x = int(input("Please enter a number: "))
        break
    except ValueError:
        print("Oops! That was no valid number. Try again...")
# Out:
# Please enter a number: 5

# %% [markdown]
# `try` statement works as follows:
# * 1st., *try clause* (statements between `try` and `except` keywords) is executed
# * If exception occurs during execution of try caluse, rest of clause is skipped.
#   - Then, if exception's type matches exception named after `except` keyword, except clause is executed, and then execution continues after the `try` statement
# * If exception occurs which doesn't match exception named in except clause, it's passed onto outer `try` statements; if no handler is found, it's an *unhandled exception* and execution stops with message as shown above

# %% [markdown]
# `try` statement may have more than 1 clause to specify handlers for different exceptions.
# - at most 1 handler will be executed.
# - handlers only handle exceptions that occur in corresponding try clause, not in other handlers of same `try` statement.
# - except clause may name multiple exceptions as a parenthesized tuple. e.g.
# ```
# except (RuntimeError, TypeError, NameError):
#   pass
#
# A class in an `except` clause is compatible with an exception if it's the same class or base class thereof
# -  (but not the other way around) - an except clause listing a derived class isn't compatible with base class.

# %%
class B(Exception):
    pass

class C(B):
    pass

class D(C):
    pass

for cls in [B, C, D]:
    try:
        raise cls()
    except D:
        print("D")
    except C:
        print("C")
    except B:
        print("B")
# Out:
# B
# C
# D

# %%
for cls in [B, C, D]:
    try:
        raise cls()
    except B:
        print("B")
    except C:
        print("C")
    except D:
        print("D")
# Out:
# B
# B
# B

# %% [markdown]
# Last except clause may omit exception name(s), to serve as wildcard. *Use this with extreme caution*, since it's easy to mask real programming error in this way!
#
# It can also be used to print an error message and then re-raise the exception (allowing a caller to **handle the exception** as well:

# %%
import sys

try:
    f = open('myfile.txt')
    s = f.readline()
    i = int(s.strip())
except OSError as err:
    print("OS error: (0)".format(err))
except ValueError:
    print("Could not convert data to an integer.")
except:
    print("Unexpected error:", sys.exc_info()[0])
    raise
# Out:
# ('Unexpected error:', <type 'exceptions.IOError'>)
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-9-0e161205e9be> in <module>()
#       2
#       3 try:
# ----> 4     f = open('myfile.txt')
#       5     s = f.readline()
#       6     i = int(s.strip())
#
# IOError: [Errno 2] No such file or directory: 'myfile.txt'

# %% [markdown]
# The `try ... except` statement has an optional *else* clause, which, when present, must follow all except clauses. It's useful for code that must be executed if the try clause doesn't raise an exception. e.g.

# %%
for arg in sys.argv[1:]:
    try:
        f = open(arg, 'r')
    except OSError:
        print('cannot open', arg)
    else:
        print(arg, 'has', len(f.readlines()), 'lines')
        f.close()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-10-5f0302380e35> in <module>()
#       1 for arg in sys.argv[1:]:
#       2     try:
# ----> 3         f = open(arg, 'r')
#       4     except OSError:
#       5         print('cannot open', arg)
#
# IOError: [Errno 2] No such file or directory: '-f'

# %% [markdown]
# The use of `else` clause is *better than adding additional code* to the `try` clause because it **avoids accidentally catching an exception that wasn't raised** by code being protected by the `try...except` statement.
#
# When exception occurs, it may have an associated value, known as exception's *argument*. Presence and type of argument depend on exception type.
#
# Except clause may specify a variable *after* exception name.
# - variable is bound to an exception instance with arguments stored in `instance.args`
# - for convenience, exception instance defined `__str__()` so arguments can be printed directly without having to reference `.args`
# - one may also instantiate an exception first before raising it and add any attributes to it as desired:

# %%
try:
    raise Exception('spam', 'eggs')
except Exception as inst:
    print(type(inst)) # the exception instance
    print(inst.args) # arguments stored in .args
    print(inst) # __str__ allows args to be printed directly,
                # but may be overridden in exception subclasses
    x, y = inst.args # unpack args
    print('x = ', x)
    print('y = ', y)
# Out:
# <type 'exceptions.Exception'>
# ('spam', 'eggs')
# ('spam', 'eggs')
# ('x = ', 'spam')
# ('y = ', 'eggs')

# %% [markdown]
# If an exception has arguments, they're printed as last part ('detail') of the message for unhandled exceptions.
#
# Exception handlers don't just handle exceptions if they occur immediately in the try clause, but also if they occur insider functions that are called (even indirectly) in the try clause. e.g.

# %%
def this_fails():
    x = 1/0
    
try:
    this_fails()
except ZeroDivisionError as err:
    print("Handling run-time error:", err)
    print(type(err))
    print(err.args)
    print(err)
    print(len(err.args))
# Out:
# ('Handling run-time error:', ZeroDivisionError('integer division or modulo by zero',))
# <type 'exceptions.ZeroDivisionError'>
# ('integer division or modulo by zero',)
# integer division or modulo by zero
# 1

# %% [markdown]
# ## Raising Exceptions
# cf. [8.4 Raising Exceptions](https://docs.python.org/3/tutorial/errors.html)
#
# The `raise` statement allows the programmer to **force a specified exception to occur**. e.g.

# %%
raise NameError('HiThere')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-72c183edb298> in <module>()
# ----> 1 raise NameError('HiThere')
#
# NameError: HiThere

# %% [markdown]
# If you need to determine whether exception was raised, but don't intend to handle it, simpler form of `raise` statement allows you to re-raise exception

# %%
try:
    raise NameError('HiError')
except NameError:
    print('An exception flew by!')
    raise
# Out:
# An exception flew by!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8452d0c3a6ab> in <module>()
#       1 try:
# ----> 2     raise NameError('HiError')
#       3 except NameError:
#       4     print('An exception flew by!')
#       5     raise
#
# NameError: HiError

# %% [markdown]
# ## User-defined Exceptions
#
# [8.5. User-defined Exceptions](https://docs.python.org/3/tutorial/errors.html)
#
# Programs may name their own exceptions by creating a new exception class.
# - Exceptions should typically *be derived from the * `Exception` class, directly or indirectly
# - Exception classes can be defined to do anything any other class can do, but usually are kept simple, often only offering a number of attributes that allow information about error to be extracted by handlers for exception.
# - When creating module that can raise several distinct errors, common practice is to create base class for exceptions defined by that module, and subclass that to create specific exception classes for different error conditions:
# - Most exceptions are defined with names that end in "Error", similar to naming of standard exceptions.
# - Many standard modules define their own exceptions to report errors that may occur in functions they define.

# %%
class Error(Exception):
    """Base class for exceptions in this module"""
    pass

class InputError(Error):
    """Exception raised for errors in the input.
    
    Attributes:
        expression -- input expression in which the error occurred
        message -- explanation of the error
    """
    
    def __init__(self, expression, message):
        self.expression = expression
        self.message = message
        
class TransitionError(Error):
    """Raised when an operation attempts a state transition that's not allowed.
    
    Attributes:
        previous -- state at beginning of transition
        next -- attempted new state
        message -- explanation of why the specific transition is not allowed
    """
    
    def __init__(self, previous, next, message):
        self.previous = previous
        self.next = next
        self.message = message

# %%
try:
    raise Error
except Error as inst:
    print(type(inst)) # the exception instance
    print(inst.args) # arguments stored in .args
    print(inst) # __str__ allows args to be printed directly,
                # but may be overridden in exception subclasses
    print(len(inst.args))
# Out:
# <class '__main__.Error'>
# ()
#
# 0

# %%
try:
    raise InputError("expression1", "message2")
except InputError as inst:
    print(type(inst)) # the exception instance
    print(inst.args) # arguments stored in .args
    print(inst) # __str__ allows args to be printed directly,
                # but may be overridden in exception subclasses
    print(len(inst.args))
except Error as inst:
    print("except Error \n")
    print(type(inst)) # the exception instance
    print(inst.args) # arguments stored in .args
    print(inst) # __str__ allows args to be printed directly,
                # but may be overridden in exception subclasses
    print(len(inst.args))
# Out:
# <class '__main__.InputError'>
# ()
#
# 0

# %%
try:
    raise TransitionError(4, 9, "message3")
except TransitionError as inst:
    print(type(inst)) # the exception instance
    print(inst.args) # arguments stored in .args
    print(inst) # __str__ allows args to be printed directly,
                # but may be overridden in exception subclasses
    print(len(inst.args))
except Error as inst:
    print("except Error \n")
    print(type(inst)) # the exception instance
    print(inst.args) # arguments stored in .args
    print(inst) # __str__ allows args to be printed directly,
                # but may be overridden in exception subclasses
    print(len(inst.args))
# Out:
# <class '__main__.TransitionError'>
# ()
#
# 0

# %%
try:
    raise TransitionError(4, 9, "message3")
except Error as inst:
    print("except Error \n")
    print(type(inst)) # the exception instance
    print(inst.args) # arguments stored in .args
    print(inst) # __str__ allows args to be printed directly,
                # but may be overridden in exception subclasses
    print(len(inst.args))
except TransitionError as inst:
    print(type(inst)) # the exception instance
    print(inst.args) # arguments stored in .args
    print(inst) # __str__ allows args to be printed directly,
                # but may be overridden in exception subclasses
    print(len(inst.args))
# Out:
# except Error
#
# <class '__main__.TransitionError'>
# ()
#
# 0

# %% [markdown]
# ### Defining Clean-up Actions
#
# [8.6 Defining Clean-up Actions](https://docs.python.org/3/tutorial/errors.html)

# %% [markdown]
# `try` statement has another optional clause which is intended to define clean-up actions that must be executed under all circumstances: `finally`
#
# `finally` clause is **always executed** before leaving `try` statement, whether an exception has occurred or not.
# When an exception has occurred in the `try` clause and has not been handled by an `except` clause (or it has occurred in an `except` or `else` clause), it's re-raised after `finally` clause has been executed.
# `finally` clause also executed "on the way out" when any other clause of the `try` statement is left via a `break`, `continue`, or `return`.

# %%
try:
    raise KeyboardInterrupt
finally:
    print('Goodbye, world!')
# Out:
# Goodbye, world!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-ca8991ac7661> in <module>()
#       1 try:
# ----> 2     raise KeyboardInterrupt
#       3 finally:
#       4     print('Goodbye, world!')
#
# KeyboardInterrupt:

# %%
try: 
    raise KeyboardInterrupt
    return 2
finally:
    print('Goodbye, world!')
# Out:
#   File "<ipython-input-24-5cca7346980d>", line 3
#     return 2
# SyntaxError: 'return' outside function

# %%
try:
    raise KeyboardInterrupt
    break
finally:
    print('Goodbye, world!')
# Out:
#   File "<ipython-input-25-551ec7cb3de8>", line 3
#     break
# SyntaxError: 'break' outside loop
